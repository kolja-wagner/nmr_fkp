# %%
# -*- coding: utf-8 -*-
"""
Auswertung: D1A

@author: kolja
"""

import matplotlib.pyplot as plt
import nmr_fkp.file_organizer as fo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bcbc6fbad29d> in <module>
#       7
#       8 import matplotlib.pyplot as plt
# ----> 9 import nmr_fkp.file_organizer as fo
#
# ModuleNotFoundError: No module named 'nmr_fkp'

# %%
# load file list
path = 'nmr_fkp/data_day_one'
file_list = fo.load_file_list(path)
selection = (fo.select_files(file_list,'meas','E'))
# load data from files
data = fo.load_files(selection)
data = fo.df_combine(data)
del(data['iout'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       2000 non-null   float64
#  1   signal_37  1998 non-null   float64
#  2   signal_38  1998 non-null   float64
#  3   signal_39  1998 non-null   float64
#  4   signal_40  1998 non-null   float64
#  5   signal_41  1998 non-null   float64
#  6   signal_42  1998 non-null   float64
#  7   signal_43  1998 non-null   float64
#  8   signal_44  1998 non-null   float64
#  9   signal_45  1998 non-null   float64
#  10  signal_46  1998 non-null   float64
#  11  signal_47  1998 non-null   float64
#  12  signal_48  1998 non-null   float64
#  13  signal_49  1998 non-null   float64
#  14  signal_50  1998 non-null   float64
#  15  signal_51  1998 non-null   float64
#  16  signal_52  1998 non-null   float64
# dtypes: float64(17)
# memory usage: 265.8 KB

# %%
# prep data
label = list(data.columns)
label.remove('time')
P = [meas.P for meas in selection]
data['time'] = data['time'] * 1000

# %%
# show different measurements
fig,ax=plt.subplots()
ran = [0,3,5,6,7,9]
for i in ran:
    data.plot(x='time', y=label[i],ax=ax,label=P[i] )
# ax.set_xlim(-2,15)
ax.legend(title='P [ms]')
ax.set_title('T1 from Period')
ax.set_xlabel('time [ms]')
ax.set_ylabel('induced voltage [V]')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c333ff75-d5d2-432c-b928-cf45631da0c3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
